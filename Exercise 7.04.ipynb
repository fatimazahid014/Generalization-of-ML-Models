# %% [markdown]
# ## **Exercise 7.04**

# %%
#@title import libraries

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#@title Loading data

_headers = ['Sex','Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']
df = pd.read_csv('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%207/abalone.csv', names=_headers, index_col=None)
df.info()

# %%
#@title split the data into 80% for training and 20% for evaluation

training_df, eval_df = train_test_split(df, train_size=0.8, random_state=1)

# %%
#@title Ebtries display
training_df.head()

# %%
eval_df.head()

# %%
#@title Importing Kfolf
from sklearn.model_selection import KFold

# %%
#@title Defining number of splits you want
n_splits = 5

# %%
#@title split the data into 80% for training and 20% for evaluation

_kf = KFold(n_splits=n_splits)

# %%
#@title create splits as _indices

_indices = _kf.split(df)

# %%
#@title create lists to hold training and validation DataFrames
_t, _v = [], []

# %%
#@title iterate over _indices

for i in range(n_splits):
    train_idx, val_idx = next(_indices)
    _train_df = df.drop(val_idx)
    _t.append(_train_df)
    _val_df = df.drop(train_idx)
    _v.append(_val_df)

# %%
#@title Iterate over the training list
for d in _t:
    print(d.info())

# %%
#@title terate over the validation list:
for d in _v:
    print(d.info())
