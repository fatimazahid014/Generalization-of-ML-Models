# %% [markdown]
# ## **Exercise 7.08**

# %%
#@title import libraries

import pandas as pd

# %%
#@title Loading data

_headers = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'car']
# read in cars dataset
df = pd.read_csv('https://raw.githubusercontent.com/PacktWorkshops/The-Data-Science-Workshop/master/Chapter07/Dataset/car.data', names=_headers, index_col=None)
df.info()

# %%
#@title encode categorical variables

_df = pd.get_dummies(df, columns=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'])
_df.head()

# %%
#@title Separating features and labels

features = _df.drop(['car'], axis=1).values
labels = _df[['car']].values

# %%
#@title Import additional libraries
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
#@title Create an instance of RandomForestClassifier
clf = RandomForestClassifier()

# %%
#@title Specify the parameters
params = {'n_estimators':[500, 1000, 2000], 'max_depth': np.arange(1, 8)}

# %%
#@title instantiate a randomized search
clf_cv = RandomizedSearchCV(clf, param_distributions=params, cv=5)

# %%
#@title  Perform the search:
clf_cv.fit(features, labels.ravel())

# %%
#@title Print the best parameter combination
print("Tuned Random Forest Parameters: {}".format(clf_cv.best_params_))

# %%
print("Best score is {}".format(clf_cv.best_score_))

# %%
#@title inspect the best model
model = clf_cv.best_estimator_
model
